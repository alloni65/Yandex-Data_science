# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Никита :)
#
# Спасибо за все исправления и комментарий
#
# Основные навыки, тестируемые на проекте:
#
#  + внимательное чтение технического задания проекта
#  + объединение разных таблиц в единый датасет, — на рабочих проектах стоит уделить особое внимание на способы объединения (left или inner, можно кого-нить забыть, значение параметра how по умолчанию), на пропуски и возможные дубликаты
#  + формирование, чтение и сравнение показателей на графике двух выборок,
#  + формирование выводов о данных по статистическим показателям,
#  + формулирование и проверку односторонних и двусторонних гипотез, <b>интерпретацию значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формирование рекомендаций для бизнеса
#
#
# <b>Поздравляю со сданным проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# Стоит поправить первые два стат теста
# <br />
#
# добавил бонус
#
# и одну ссылку [Функции в Python](https://www.codecamp.ru/blog/python-functions/?ysclid=loyw96tz7822158015)

# %% [markdown]
# ## Сервис аренды самокатов GoFast

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍🤝

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Никита :)
#
# Критические ❌ комментарии:
#
#  + добавить название проекту
#  + в разделе проверки гипотез поправить выборки для первых двух стат тестов и изменить вывод в третьем
#
# новые подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Никита :) Спасибо за вопросы
#
# Критические ❌ комментарии:
#
#  + добавить название проекту  !Не могу изменить название проекта. Вылезает ошибка, которая не дает отправить проект на проверку.
#  + поправить все графики на проекте ❌
#  + поправить расчет выручки  ❌
#  + в разделе проверки гипотез поправить Н1 в первом стат тесте и выводы у всех трех стат тестов ❌
#
# новые подсказки добавил

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Юпитер на базе Яндекс практикума отвратительно работал последние дни. Постоянно вылетают какие-то ошибки. В связи с чем я теряю очень много времени (эта версия проекта была готова в воскресенье, вечером). Так как в пачке не дописаться, прошу Вас уведомить ответственных.
#
#         Название проекту добавил.
#         Не понимаю, как переделать графики, чтобы они прошли Вашу проверку. Все предыдущие проекты графики проходили без рецензирования.
#         Данные о размахе были добавлены в данной версии.
#         Выручку в дф total поправил.
#         Выводы поправил, хотя и не совсем понял, что изменилось в итоге.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо, что подсветил проблему с юпитером, и со своей стороны приношу извинения за эти неполадки. Если существует возможность настроить локальное рабочее место, стоит воспользоваться. Готовые проекты можно отправлять в виде файлов
#
#
# Про графики — требования к оформлению проектов растут с каждым новым проектом, то что принималось на проекте по предобработке, на этом проекте с высокой вероятностью попадет в разряд критических, не стоит этому удивляться. У графика должно быть название, и подписаны все оси, например
#
# ![image.png](attachment:image.png)
#
# на моем графике неудачная легенда, из которой непонятно, что это такое: 0 и 199
#
#     Название проекту добавил.
#
# Кажется не сохранилось название
#
# Остальные ответы по месту

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Никита :) Спасибо за доработки
#
# Критические ❌ комментарии:
#
#  + добавить название проекту - это важно, проект без названия никого не заинтересует +
#  + поправить все графики на проекте
#  + добавить статистики в исследовательский раздел → данные о межквартильном размахе для трех параметров
#  + поправить расчет выручки
#  + в разделе проверки гипотез поправить выводы
#
# подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Никита :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# а подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали

# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера </b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется весь код на проекте запускался вручную ... 178-я строка кода в начале проекта
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# Проверить работоспособность кода — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
data_users = pd.read_csv('/datasets/users_go.csv')
data_rides = pd.read_csv('/datasets/rides_go.csv')
data_subs = pd.read_csv('/datasets/subscriptions_go.csv')

# %% [markdown]
# При помощи функции pandas 'read_csv' загрузим наши датафреймы.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если при загрузке данных добавить параметр `parse_dates: parse_dates=['date']` то тип данных автоматически переведется в даты. Подробнее про это можно прочитать по ссылке ниже
#
# https://newtechaudit.ru/gruzi-daty-krasivo/

# %%
print(data_users.head(), data_users.info())
print(data_rides.head(), data_rides.info())
print(data_subs.head(), data_subs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все  методы можно собрать в функцию и оптимизировать код вывода первичной информации
#
#         dataset.head()
#         dataset.info()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте

# %% [markdown]
# Выведем общую информацию по датафреймам, а так же первые 5 строк для ознакомления.
#
# На первый взгляд, количество строк внутри датафреймов совпадает.
#
# Общее количество пользователей до обработки: 1565
#
# Общее количество поездок до обработки: 18068
#
# Общее количество подписок: 2

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Обзор данных выполнен, применены методы .head() и .info(), промежуточный вывод добавлен, молодец

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %%
data_rides['date'] = pd.to_datetime(data_rides['date'])
data_rides['month'] = pd.DatetimeIndex(data_rides['date']). month
print(data_rides.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
#  4   month     18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB
# None

# %% [markdown]
# Изменим тип данных в столбце date (с object на datetime).
# Так же, для будущих исследований, создадим новый столбец month с месяцем совершения аренды самоката.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит проверить — за какой период (год или несколько лет) у нас собраны данные
#
# ![image-2.png](attachment:image-2.png)

# %%
print(data_users.isna().sum())
print(data_rides.isna().sum())
print(data_subs.isna().sum())
#print(data_users.duplicated().sum())
data_users = data_users.drop_duplicates()
#print(data_users.duplicated().sum())
#print(data_rides.duplicated().sum())
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Исходя из проверки, можем подтвердить отсутствие пропусков в значениях. Предполагаю, что в датафрейме data_users строка user_id 100% должна состоять из уникальных значений. На текущий момент, в столбце user_id находится 31 дубликат. Для того, чтобы понять, не ошибка ли в дубликатах user_id, проверим, является ли вся строка, хранящая в себе дубликат user_id, дубликатом. Количество строк совпадает, следовательно, строки явялются явными дубликатами, которые следует удалить.
#
# В датафрейме data_rides явных дубликатов обнаружено не было.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %%
print(data_rides[data_rides['distance'] < 1000].sort_values(by = 'distance'))
plt = data_rides['distance'].plot(x = 'distance' , kind = 'hist', bins = 100, figsize = (10,5), grid = True)
plt.set_xlabel('Дистанция, м')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пройденного расстояния')
data_rides['speed'] = data_rides['distance'] / data_rides['duration']
print(data_rides.sort_values(by = 'speed', ascending = False))
data_rides['duration'].groupby(data_rides['duration']).count()
# Out:
#        user_id    distance   duration       date  month
# 11555     1069    0.855683  10.001902 2021-01-31      1
# 9541       925    2.570787   3.011018 2021-10-19     10
# 13690     1223    4.329506   4.008958 2021-05-22      5
# 8658       861    6.784447   6.015656 2021-07-21      7
# 7841       796    7.097072  10.026614 2021-11-26     11
# ...        ...         ...        ...        ...    ...
# 4036       435  997.123898  10.988496 2021-04-22      4
# 6451       694  997.162454  11.849036 2021-02-24      2
# 12470     1137  998.068860  12.303236 2021-01-15      1
# 13533     1213  998.581428  10.992907 2021-01-29      1
# 2709       289  999.531884   8.855805 2021-03-01      3
#
# [1372 rows x 5 columns]
#        user_id     distance   duration       date  month         speed
# 16309     1411  7211.007745   0.500000 2021-04-15      4  14422.015489
# 17242     1477  6724.932981   0.500000 2021-01-12      1  13449.865963
# ...

# %% [markdown]
# Изучив данные в столбце 'distance', заметим, что данные в стобце 'distance' записаны неправильно (м/км). В этих спорных строках, в столбце 'duration', стабильное значение 0.5. Избавимся от всех данных, где подозрительная продолжительность поездки = 0.5, когда будем объединять датафреймы.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Комментарий ревьюера</b></font>
#     <br />
#         <font size="3", color = "black">
#             <br />
#
#         Изучив данные в столбце 'distance', заметим, что данные в стобце 'distance' записаны неправильно (м/км).
#
# Хорошее предположение
#
#         11555     1069    0.855683  10.001902 2021-01-31      1
#         9541       925    2.570787   3.011018 2021-10-19     10
#
# Это возможно сбоит  модуль определения расстояния, т.к. 855 метров за 10 минут и 2570 за 3 минуты очень странные скорости для поездки на самокате, кажется здесь причина ошибки в данных сложнее. Стоит отдать этот случай в техническую службу

# %%
data_users['name'] = data_users['name'].str.lower()
data_users['city'] = data_users['city'].str.lower()

# %% [markdown]
# Чтобы в последующих исследованиях избежать некорректных выводов, избавимся от верхних регистров в именах и названиях городов.

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %%
#print(data_users.groupby('city').count().plot(figsize = (10, 5)))
city = data_users['city'].unique()
values = [data_users[data_users['city'] == c]['city'].count()for c in city]
frame = {'Город': city, 'Частота': values}
freq = pd.DataFrame(frame)
freq = freq.sort_values(by = 'Частота', ascending = False)
freq.reset_index(drop = True, inplace = True)
print(freq)
plt = freq.plot(x='Город', y="Частота", kind='bar', figsize=(10,5), grid = True)
plt.set_xlabel('Город')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пользователей по городам')
# Out:
#             Город  Частота
# 0       пятигорск      219
# 1    екатеринбург      204
# 2  ростов-на-дону      198
# 3       краснодар      193
# 4            сочи      189
# 5            омск      183
# 6          тюмень      180
# 7          москва      168
# Text(0.5, 1.0, 'График распределения пользователей по городам')

# %% [markdown]
# Начнем исследование с анализа частоты встречаемости городов. Исходя из полученного датафрейма, а так же визуализации, можем заметить, что самым сервис Gofast очень популярен в городе Пятигорск, но не особо пользуется спросом в столице России.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит указать на сколько %-ов отличается кол-во пользователей в разных городах, стоит ли говорить о такой разнице?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Молодец, ты построил график с барами, добавил таблицу значений и вывод
#
# Стоит развернуть график в горизонтальные бары, если надписи оси Х не умещаются в горизонтальном виде
#
# Можно скрыть легенду, она будет дублировать название графика

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью оформить все графики на проекте
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %%
subs = {'Тип подписки':
        data_users['subscription_type'].unique(), 
        'Частота': 
        [data_users[data_users['subscription_type']==typ]['subscription_type'].count() 
         for typ in data_users['subscription_type'].unique()]
       }
subs_df = pd.DataFrame(subs)
print(subs_df)
plt = subs_df.plot(x = 'Тип подписки', y = 'Частота', kind = 'bar', figsize = (5,3))
plt.set_xlabel('Подписка')
plt.set_ylabel('Кол-во пользователей')
plt.set_title('График распределения пользователей по подпискам')
# Out:
#   Тип подписки  Частота
# 0        ultra      699
# 1         free      835
# Text(0.5, 1.0, 'График распределения пользователей по подпискам')

# %% [markdown]
# Произведем аналогичные расчеты для параметра подписки. Насколько мы можем видеть, Количество пользователей с подпиской и без распределено примерно 40 на 60. Лидируют по частоте пользователи без подписки.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Можно использовать круговую диаграмму для отображения разности в доле клиентов

# %%
plt = data_users.plot(kind = 'hist', y ='age', bins = 30, figsize = (10,5), grid = True)
plt.set_xlabel('Возраст')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пользователей по возрасту')
print('Средний возраст пользователя: ',data_users['age'].mean())
print('Межквартильный размах:', stats.iqr(data_users['age']))
# Out:
# Средний возраст пользователя:  24.903520208604956
# Межквартильный размах: 6.0

# %% [markdown]
# При анализе возраста юзеров, было рассчитано среднее, а так же построена гистограмма. По итогам анализа, можно сделать вывод, что средний возраст пользователя - 25 лет, распределение на гистограмме стремится к нормальному. Межквартильный размах возраста равен 6. Значит, что основная аудитория - молодежь.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличная автоматизация расчета межквартильного размаха, молодец

# %%
plt = data_rides['distance'].plot(y = 'distance', kind = 'hist', bins = 50, figsize = (10,5), grid = True )
plt.set_xlabel('Дистанция, м')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пройденного расстояния')
print('Средний расстояние поездки: ',data_rides['distance'].mean())
print('Межквартильный размах:', stats.iqr(data_rides['distance']))
# Out:
# Средний расстояние поездки:  3070.6599756818814
# Межквартильный размах: 1232.9963753558854

# %% [markdown]
# Среднее расстояние поездки - 145 метров. Маловато. Возможно люди берут самокат, чтобы доехать от автобусных остановок/ станций метро до ближайшего пункта сдачи самоката. Размах чуть больше километра показывает неоднородность дистанций, которые проезжают клиенты.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />Можно добавить свои предположения, по какой причине у нас пользователи разделились на две части: совершают короткие и длинные поездки, с пиками около 700-а и 3100-а метров

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить промежуточный вывод о результатах выполнения исследовательских задач и сведения о межквартильном размахе в данных:
#
# + по возрасту, длительности и пройденному расстоянию
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Шаг 4. Объединение данных

# %%
total_df = data_users.merge(data_rides, how='inner', on='user_id', left_on=None, right_on=None, left_index=False)
total_df = total_df[total_df['duration'] != 0.5].sort_values(by = 'speed', ascending = False)
total_df = total_df[total_df['speed'] < 416].sort_values(by = 'speed', ascending = False)
total_df = total_df.merge(data_subs, how='inner', on='subscription_type', left_on=None, right_on=None, left_index=False )
plt = total_df['distance'].plot(y = 'distance', kind = 'hist', bins = 45, figsize = (10,5), legend = True, grid = True )
plt.set_xlabel('Дистанция, м')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пройденного расстояния')
total_df['duration'] = np.ceil(total_df['duration'])
print(total_df.head())
print(total_df.info())
# Out:
#    user_id     name  age            city subscription_type     distance  \
# 0     1078  василий   23       пятигорск              free  4888.505444
# 1     1163    денис   32       пятигорск              free  4880.702286
# 2     1524   матвей   32          москва              free  4829.325021
# 3     1379   регина   17  ростов-на-дону              free  4531.850739
# 4     1128  георгий   27       краснодар              free  4516.806367
#
#    duration       date  month       speed  minute_price  start_ride_price  \
# 0      12.0 2021-09-01      9  415.088811             8                50
# 1      12.0 2021-06-15      6  414.976141             8                50
# 2      12.0 2021-08-20      8  414.226776             8                50
# 3      12.0 2021-10-28     10  409.614336             8                50
# 4      12.0 2021-10-06     10  409.367854             8                50
#
#    subscription_fee
# 0                 0
# 1                 0
# 2                 0
# ...

# %% [markdown]
# Датафреймы data_users и data_rides были объеденины в единый total_df. Как мы уже говорили ранее, избавимся от подозрительных выбросов. Дополнительно проанализируем связку время - расстояние. Рассчитаем скорость. Исходя из скоростных ограничений Яндекса (25 км/ч), переведем км/ч в м/м и получим максимальную возможную скорость юзеров, равную 416 м/м. Избавимся от вероятных выбросов по скорости. После объединения данных в датафрейм total_df общее количество строк - 17.969, что эквивалентно изначально датафрейму data_rides.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Объединение данных прошло по плану, молодец
#
#
#
# Обрати внимание на параметры, которые пандас выставляет по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении
#
#
# [Примеры объединения таблиц, merge](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge)
#
# [Примеры объединения таблиц, join](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.join.html?highlight=join#pandas.DataFrame.join)

# %% [markdown]
#  <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит проверить размерность  до объединения и после у полученной таблицы, чтобы размерность ДО == размерности после (по кол-ву строк), и наличие пропусков после объединения.
#
# Можно добавить минивывод о результатах этой важной операции

# %%
subs1_df = total_df[total_df['subscription_type'] == 'ultra']
subs0_df = total_df[total_df['subscription_type'] == 'free']
print(subs0_df.info())
print(subs1_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11469 entries, 0 to 11468
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            11469 non-null  int64
#  1   name               11469 non-null  object
#  2   age                11469 non-null  int64
#  3   city               11469 non-null  object
#  4   subscription_type  11469 non-null  object
#  5   distance           11469 non-null  float64
#  6   duration           11469 non-null  float64
#  7   date               11469 non-null  datetime64[ns]
#  8   month              11469 non-null  int64
#  9   speed              11469 non-null  float64
#  10  minute_price       11469 non-null  int64
#  11  start_ride_price   11469 non-null  int64
#  12  subscription_fee   11469 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(3)
# memory usage: 1.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Разделим наш полный датафрейм на данные по юзерам с подпиской и без. С разделенными датафреймами все хорошо - пропусков нет.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не совсем понимаю, как после разделения датафрейма, могли появиться пропуски, но информацию подтянул. Пропусков нет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Это один из элементов автоматической проверки, создали таблицу → проверили размерность и наличие пропусков

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит проверить наличие пропусков и размерность полученных таблиц после разделения - и зафиксировать результаты в минивыводе

# %%
subs1_df['distance'].plot(kind = 'hist', figsize = (10,5), bins = 50)
plt = subs0_df['distance'].plot(kind = 'hist', figsize = (10,5), bins = 50, alpha = 0.5, grid = True)
plt.set_xlabel('Дистанция, м')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения пройденного расстояния')
# Out:
# Text(0.5, 1.0, 'График распределения пройденного расстояния')

# %% [markdown]
# Люди с подпиской чаще всего пользуются услугами самокатов для путешествий на расстояние в 3 км. Размах частот небольшой. Возможно, это связано с тем, что люди с подпиской - постояльцы, которые пользуются одними маршрутами.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Подсвечу еще раз
#
#         стоит полностью оформить все графики на проекте

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для каждого графика на проекте добавляем
#
# + название
# + подпись оси Х
# + подпись оси У
#
#
#         Подсвечу еще раз
#
#         стоит полностью оформить все графики на проекте

# %% [markdown]
# Люди без подписок более разношерстны. Их средняя дистанция - от 2 до 4,5 км. Относительно подписчиков, данная каста потребителей гораздо чаще берут самокат на расстояние до 1 км.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#         <AxesSubplot:ylabel='Frequency'>
#
# subs0_df['distance'].plot(kind = 'hist', figsize = (10,5), bins = 50);

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит совместить гистограммы на одном виде, по две гистограммы для каждого параметра, чтобы появилась возможность визуально сравнить параметры у двух разных групп клиентов

# %%
subs1_df['duration'].plot(kind = 'hist', figsize = (10,5), bins = 10);
print(subs1_df.describe())
plt = subs0_df['duration'].plot(kind = 'hist', figsize = (10,5), bins = 10, alpha = 0.6, grid = True);
print(subs0_df.describe())
plt.set_xlabel('Продолжительность поездки, мин')
plt.set_ylabel('Частота, шт')
plt.set_title('График распределения времени поездки')
# Out:
#            user_id          age     distance     duration        month  \
# count  6500.000000  6500.000000  6500.000000  6500.000000  6500.000000
# mean    348.725385    24.892615  3115.445388    19.037692     6.422308
# std     201.099339     4.757208   836.895330     5.577439     3.414616
# min       1.000000    12.000000   244.210438     4.000000     1.000000
# 25%     175.000000    22.000000  2785.444017    15.000000     4.000000
# 50%     351.000000    25.000000  3148.637229    19.000000     6.000000
# 75%     525.000000    28.000000  3560.574425    22.000000     9.000000
# max     699.000000    38.000000  5699.769662    41.000000    12.000000
#
#              speed  minute_price  start_ride_price  subscription_fee
# count  6500.000000        6500.0            6500.0            6500.0
# mean    175.988183           6.0               0.0             199.0
# std      55.677720           0.0               0.0               0.0
# ...

# %% [markdown]
# Подписчики, в среднем катаются на самокатах 13 - 23 минут. Насколько я понимаю, постояльцы с подпиской катаются по одним маршрутам и за одинаковый временной интервал.

# %% [markdown]
# Аналогично с выводами по дистанции, аудитория без подписки скорее всего гораздо более разношерстна. Предполагаю, что частота использования пользователями самоката гораздо меньше.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить сравнение статистик у двух групп пользователей  в промежуточный вывод раздела. Это сравнение является важным для маркетологов при помощи метода
#
#     .describe()

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Опять же не совсем понимаю, как влияет округление до слияния и после. Но сделаем.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         3.3 → 4
#         4.5 → 5
#         10.5 → 11
#
# Сумма первой колонки 18.3, округление выполняем после агрегации → 19
#
# И сумма по второй колонке 19, превращается в 20
#
# Только на одном округлении можно заработать 6 или  8 рублей. В масштабах всей компании разница будет существенной

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит выполнить округление длительности до агрегации данных
#
# ![image.png](attachment:image.png)

# %%
df = data_users.merge(data_subs, how ='inner', on='subscription_type', left_on=None, right_on=None, left_index=False)
data_rides['duration'] = np.ceil(data_rides['duration'])
df = df.merge(data_rides, how ='inner', on='user_id', left_on=None, right_on=None, left_index=False)
df['revenue'] = df['start_ride_price'] + (df['minute_price'] * df['duration']) 
df['subscription_fee'] = df['subscription_fee'].astype(float)
print(df.head())
df0 = df[df['subscription_fee'] < 10]
df1 = df[df['subscription_fee'] > 10]
df_1 = df[df['subscription_fee'] > 10]
# Out:
#    user_id  name  age    city subscription_type  minute_price  \
# 0        1  кира   22  тюмень             ultra             6
# 1        1  кира   22  тюмень             ultra             6
# 2        1  кира   22  тюмень             ultra             6
# 3        1  кира   22  тюмень             ultra             6
# 4        1  кира   22  тюмень             ultra             6
#
#    start_ride_price  subscription_fee     distance  duration       date  \
# 0                 0             199.0  4409.919140      26.0 2021-01-01
# 1                 0             199.0  2617.592153      16.0 2021-01-18
# 2                 0             199.0   754.159807       7.0 2021-04-20
# 3                 0             199.0  2694.783254      19.0 2021-08-11
# 4                 0             199.0  4028.687306      27.0 2021-08-28
#
#    month       speed  revenue
# 0      1  172.264021    156.0
# 1      1  165.493673     96.0
# 2      4  121.011887     42.0
# 3      8  145.577402    114.0
# ...

# %%
df_pivot=df.groupby(['month', 'user_id', 'subscription_type']).agg({'distance': ['sum'],
                                                'speed':['count'],
                                               'duration': ['sum'],
                                            'subscription_fee' :['max'],
                                               'revenue': ['sum']
                                              })
df = pd.DataFrame(df_pivot)
cols = ['revenue', 'subscription_fee']
df['revenue'] = df[cols].sum(axis= 1 )
df_pivot_0=df0.groupby(['month', 'user_id', 'subscription_type']).agg({'distance': ['sum'], 
                                                'speed':['count'],
                                               'duration': ['sum'],
                                            'subscription_fee' :['max'],
                                               'revenue': ['sum']
                                              })
df0 = pd.DataFrame(df_pivot_0)
cols = ['revenue', 'subscription_fee']
df0['revenue'] = df0[cols].sum(axis= 1 )
df_pivot_1=df1.groupby(['month', 'user_id', 'subscription_type']).agg({'distance': ['sum'],
                                                'speed':['count'],
                                               'duration': ['sum'],
                                            'subscription_fee' :['max'],
                                               'revenue': ['sum']
                                              })
df1 = pd.DataFrame(df_pivot_1)
cols = ['revenue', 'subscription_fee']
df1['revenue'] = df1[cols].sum(axis= 1 )

# %%
df['revenue'].sum()
# Out:
# sum    3878641.0
# dtype: float64

# %%
# check
df_pivot['user_id'] = df_pivot.index.get_level_values(1)
df_pivot
# Out:
#                                     distance speed duration subscription_fee  \
#                                          sum count      sum              max
# month user_id subscription_type
# 1     1       ultra              7027.511294     2     42.0            199.0
#       3       ultra              3061.777147     1     13.0            199.0
#       5       ultra              3914.646990     1     13.0            199.0
#       7       ultra              6478.080979     2     28.0            199.0
#       12      ultra              3577.151148     1     33.0            199.0
# ...                                      ...   ...      ...              ...
# 12    1525    free               4597.854350     1     34.0              0.0
#       1526    free               3644.121544     1     23.0              0.0
#       1528    free               3998.569324     1     11.0              0.0
#       1532    free               6111.889853     2     42.0              0.0
# ...

# %% [markdown]
# ### check

# %%
df_pivot[df_pivot['user_id'] == 1]
# Out:
#                                     distance speed duration subscription_fee  \
#                                          sum count      sum              max
# month user_id subscription_type
# 1     1       ultra              7027.511294     2     42.0            199.0
# 4     1       ultra               754.159807     1      7.0            199.0
# 8     1       ultra              6723.470560     2     46.0            199.0
# 10    1       ultra              5809.911100     2     32.0            199.0
# 11    1       ultra              7003.499363     3     56.0            199.0
# 12    1       ultra              6751.629942     2     28.0            199.0
#
#                                 revenue user_id
#                                     sum
# month user_id subscription_type
# 1     1       ultra               252.0       1
# 4     1       ultra                42.0       1
# 8     1       ultra               276.0       1
# 10    1       ultra               192.0       1
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изменить способ расчета выручки, сейчас мы стоимость подписки добавили только один раз за год — в январе 2021 года в таблице
#
#         df_pivot
#
# Стоит использовать твою первоначальную выборку → в df уже все подсчитано, осталось только вытащить название подписки из индекса, чтобы можно было выполнить два стат теста

# %%
df.head()
# Out:
#                                     distance speed duration subscription_fee  \
#                                          sum count      sum              max
# month user_id subscription_type
# 1     1       ultra              7027.511294     2     42.0            199.0
#       3       ultra              3061.777147     1     13.0            199.0
#       5       ultra              3914.646990     1     13.0            199.0
#       7       ultra              6478.080979     2     28.0            199.0
#       12      ultra              3577.151148     1     33.0            199.0
#
#                                 revenue
#                                     sum
# month user_id subscription_type
# 1     1       ultra               451.0
#       3       ultra               277.0
#       5       ultra               277.0
#       7       ultra               367.0
#       12      ultra               397.0

# %%
df.revenue.sum()
# Out:
# sum    3878641.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Выручка в df подсчитана корректно, используем эту выборку. А для исследования — просто делим её по видам подписки
#
# Создать отдельную колонку из составного индекса можно при помощи кода, пример ⬆⬆⬆
#
#         df_pivot['user_id'] = df_pivot.index.get_level_values(1)

# %%
# import numpy as np
# df = data_users.merge(data_subs, how ='inner', on='subscription_type', left_on=None, right_on=None, left_index=False)
# people = df['user_id'].unique()
# dist = [total_df[total_df['user_id']==ids]['distance'].sum() for ids in people]
# dur = [total_df[total_df['user_id']==ids]['duration'].sum() for ids in people]
# minute = [df[df['user_id'] == ids]['minute_price'] for ids in people]
# start = [df[df['user_id'] == ids]['start_ride_price'] for ids in people]
# sub_fee = [df[df['user_id'] == ids]['subscription_fee'] for ids in people]
# rev = {'Пользователь': people, 'Суммарное расстояние': dist,
#        'Суммарное время': dur,'Стоимость минуты': minute,
#        'Начало поездки': start, 'Стоимость подписки': sub_fee
#       }
# rev_df = pd.DataFrame(rev).sort_values(by = 'Пользователь')
# rev_df['Выручка'] = ((rev_df['Начало поездки'] * rev_df['Количество поездок'])
# + (rev_df['Стоимость минуты'] * rev_df['Суммарное время'])) + rev_df['Начало поездки']
#print(rev_df)
# rev0_df = rev_df[rev_df['Стоимость подписки'] < 100]
# rev1_df = rev_df[rev_df['Стоимость подписки'] > 100]
# print(rev0_df['Суммарное время'].plot(kind = 'hist', bins = 35, figsize = (5,3)))
# print(rev1_df['Суммарное время'].plot(kind = 'hist', bins = 35, figsize = (5,3), alpha=0.6))

# %%
# df = data_users.merge(data_subs, how ='inner', on='subscription_type', left_on=None, right_on=None, left_index=False)
# data_rides['duration'] = np.ceil(data_rides['duration'])
# total = df.merge(data_rides, how ='inner', on='user_id', left_on=None, right_on=None, left_index=False)
# total['amount'] = [total[total['user_id'] == i]['user_id'].count() for i in total['user_id']]
# total0 = total[total['subscription_fee'] < 10]
# total1 = total[total['subscription_fee'] > 10]
# total['revenue'] = (total['start_ride_price'] * total['amount']) + (total['minute_price'] * total['duration'])     
# #pivot = pd.pivot_table(total, columns = 'month', index = 'user_id', values = 'revenue', aggfunc = sum).fillna(0)
# #print(pivot)
# print(total.head())

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Комментарий ревьюера в2</b></font>
#     <br />
#         <font size="3", color = "black">
#             <br />
# Можно без print(), если строка кода стоит последней

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте

# %% [raw]
# Сформируем вспомогательный датафрейм df, который является слиянием data_subs и data_users. С помощью этого датафрейма, а так же датафрейма total_df, создаем таблицу, с агрегированными данными по продолжительности поездок, их числу и расстоянию. Для расчета выручки в датафрейм были добавлены все необходимые данные из df.

# %%
# pivot.head().T

# %%
data_rides.duration.sum()
# Out:
# 330708.0

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал сводную таблицу. На всякий случай оставил предыдущую таблицу закомментированной.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит переделать сводную таблицу, сейчас она не пригодна для выполнения стат тестов — в таблице должна быть запись о ежемясячной выручке по каждому пользователю, примерно около 11 000 строк
#
# В твоем алгоритме не учтена стоимость ежемесячной подписки на тарифе - с подпиской 199 рублей каждый месяц
#
# стоит учесть, что пользователь мог подписаться только в июле
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Сводная таблица в pandas](https://dfedorov.spb.ru/pandas/%D0%A1%D0%B2%D0%BE%D0%B4%D0%BD%D0%B0%D1%8F%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D0%B0%20%D0%B2%20pandas.html?ysclid=lje9wz2vfc28794921)

# %%
# check
# total[total['user_id'] == 1][['user_id', 'distance', 'date', 'month', 
#        'subscription_type', 'minute_price', 'start_ride_price',
#        'subscription_fee', 'amount', 'duration', 'revenue']]

# %%
# check
# total[total['user_id'] == 1534][['user_id', 'distance',   'date', 'month', 
#        'subscription_type', 'minute_price', 'start_ride_price',
#        'subscription_fee', 'amount', 'duration', 'revenue']]

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Справедливо, что на среднесрочной и долгосрочной перспективе люди без подписки платят кратно больше. Если человек без подписки воспользовался услугами 15 раз, то есть оплата равна 15*50 + Pr * Qmin + Sub. fee. Вы проверяете таблицу total. В качестве ответа на данный пункт задачи была сделана сводная таблица - pivot.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить расчет в сводной таблице, мы кратно завысили размер оплаты для пользователей без подписки

# %%
# pivot.head(2)

# %%
# check
# total[total['user_id'] == 1][['user_id', 'distance', 'date', 'month', 
#        'subscription_type', 'minute_price', 'start_ride_price',
#        'subscription_fee', 'amount', 'duration', 'revenue']].head(3)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить расчет в сводной таблице
#
# Берем пользователя №1, с подпиской, он катался в январе 21 года два раза, заплатил подписку 199 рублей, накатал 42 минуты * 6 рублей, получается 451 рубль
#
# У тебя в расчете 325.
#
# ![image.png](attachment:image.png)
#
# В другой таблице ошибки также присутствуют
#
# ![image-2.png](attachment:image-2.png)
#
# __Стоит пересмотреть весь подход к расчету выручки и перепроверить выборочно выручку у 3-х пользователей из каждой группы, когда исправишь__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Другой интересный вопрос, который мы должны отнести в тех. службу — все ли у нас в порядке с данными — человек покупает подписку в декабре и январе, но не покупает её в июне, июле и сентябре ...

# %% [markdown]
# #### Шаг 7. Распределения

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не понимаю, что не так. Переписал гипотезы, но не понимаю, что изменилось.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить весь код, чтобы он работал с новыми выборками
#
#         total1, total0
#
# этих выборок уже нет

# %%
df.head(2)
# Out:
#                                     distance speed duration subscription_fee  \
#                                          sum count      sum              max
# month user_id subscription_type
# 1     1       ultra              7027.511294     2     42.0            199.0
#       3       ultra              3061.777147     1     13.0            199.0
#
#                                 revenue
#                                     sum
# month user_id subscription_type
# 1     1       ultra               451.0
#       3       ultra               277.0

# %%
df.columns
# Out:
# MultiIndex([(        'distance',   'sum'),
#             (           'speed', 'count'),
#             (        'duration',   'sum'),
#             ('subscription_fee',   'max'),
#             (         'revenue',   'sum')],
#            )

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# В этой выборке придется избавиться от мультииндекса (частичный пример добавлен после расчета выручки),  или работать со сложными названиями колонок

# %%
from scipy import stats as st
import numpy as np

alpha = 0.05

results = st.ttest_ind(df1['duration'], df0['duration'], alternative = 'greater')
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# p-значение: [1.]
# Нет оснований отвергнуть нулевую гипотезу

# %%
df1['duration']
# Out:
#                                   sum
# month user_id subscription_type
# 1     1       ultra              42.0
#       3       ultra              13.0
#       5       ultra              13.0
#       7       ultra              28.0
#       12      ultra              33.0
# ...                               ...
# 12    688     ultra              24.0
#       689     ultra              19.0
#       692     ultra              15.0
#       694     ultra              18.0
#       699     ultra              26.0
#
# [4533 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Извини, в двух первых стат тестах мы не используем агрегированные выборки, я ошибся с советом. Здесь используем
#
#         subs1_df['duration'] и subs0_df['duration']
#
# мы должны стат тест проводить на сырых данных, неагрегированных по месяцам.
#
# Это только выручку мы сравниваем ежемесячную, т.к. это первичный уровень данных, выручку по другому не сравнить (ежемесячную)

# %% [markdown]
# H0: Пользователи с подпиской и без проводят на самокатах одинаковое количество времени.
#
# H1: Пользователи с подпиской проводят больше времени, чем люди без подписки.
#
# Судя по результатам Т-теста, пользователи с подпиской, скорее всего, проводят на самокате бОльшее количество времени, чем люди без подписки.
# Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить
#
#         Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в4</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в4</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит исправить Н1 и вывод
#
#         H1: Пользователи с подпиской и без проводят на самокатах разное количество времени.
#
#         Судя по результатам Т-теста, пользователи с подпиской и без, скорее, пользуются услугами сервиса одинаковое количество времени. Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.
#
#
# Пример корректной Н1 и проверки гипотезы, окончание примера стоит прочитать в тренажере
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Н0 у тебя
#
#     H0: Пользователи с подпиской и без проводят на самокатах одинаковое количество времени.
#     H1: Пользователи с подпиской дольше катаются на самокатах.
#
# Расчет показал, что
#
#     p-значение: 2.4959453720736625e-34
#     Отвергаем нулевую гипотезу
#
# Если мы отвергаем Н0, то стоит поправить вывод
#
#     Судя по результатам Т-теста, пользователи с подпиской пользуются услугами сервиса одинаковое количество времени. Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Н0 у тебя
#
#     H0: Пользователи с подпиской и без проводят на самокатах одинаковое количество времени.
#     H1: Пользователи с подпиской дольше катаются на самокатах.
#
# Расчет показал, что
#
#     p-значение: 2.4959453720736625e-34
#     Отвергаем нулевую гипотезу
#
# Если мы отвергаем Н0, то стоит поправить вывод
#
#     Судя по результатам Т-теста, пользователи с подпиской пользуются услугами сервиса одинаковое количество времени. Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.
#
# Пример расшифровки р-значения ⬇⬇⬇
#
#         Значение P-value, стремящееся к нулю, означает, что значения выборок очень близки друг к другу.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы (Н0 и Н1) не сформулированы

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         if results.pvalue < alpha:
#             print('Время поездки одинаковое')
#         else:
#             print('Время поездки подписчиков больше')
#
# Стоит поправить код проверки результата стат теста под Н0 и Н1
#
#         Нулевая и альтернативная гипотезы не сформулированы

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 5.724726232485101e-28

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит дополнить вывод
#
#         Если да, то пользователи с подпиской могут быть «выгоднее» для компании.
#
# выгодно ли это бизнесу или нет
#
# И какие это пользователи — средние, суммарные, медианные?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В данном ст-тесте приходится использовать иной дф, потому что задача заключается в использовании данных за каждую поездку.

# %%
interested_value = 3120 
alpha = 0.05
results = st.ttest_1samp(df_1['distance'], interested_value, alternative = 'greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.6695786037226972
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# H0: Расстояние, которое проезжает подписчик равно 3120 м.
#
# H1: Расстояние, которое проезжает подписчик, больше 3120 м.
#
# Исходя из полученного результата можно предположить, что подпичики проезжают целевые 3120 м. Самокаты не подвержены ускоренной порче.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         Исходя из полученного результата нельзя утверждать, что подпичики проезжают целевые 3120 м. Скорее всего износ самокатов может быть выше предполагаемого. Это может сказаться на итоговой чистой прибыли.
#
#
# Стоит поправить вывод, если  у нас Н1 говорит, что
#
#         H1: Расстояние, которое проезжает подписчик, больше 3120 м.
#
# и мы не смогли отвергнуть Н0, а значит не приблизились к Н1, то каким образом мы можем говорить в выводе, что пользователь проезжает больше? Н0 у нас
#
#         H0: Расстояние, которое проезжает подписчик равно 3120 м.
#
# и результат стат теста
#
#         p-значение: 0.6695786037226972
#         Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить все выводы, добавить акценты с точки зрения бизнеса

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы не сформулированы

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить вывод, исходя из Н0 и Н1, т.к. мы не смогли отвергнуть Н0
#
#         Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров? Расстояние, которое проезжает подписчик - меньше 3120 м

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В данном случае стоит использовать параметр alternative = 'greater'. Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального"
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я, скорее всего, не совсем понятно сделал вывод. Речь идет о том, что денег подписчики и люди без подписки приносят разное количество. Акцент на рекламной кампании был сделан, потому что подписчики приносят больше прибыли. Если случится переход доли юзеров в подписчиков, то прибыли станет еще больше.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %%
alpha = 0.05

results = st.ttest_ind(df1['revenue'], df0['revenue'], alternative = 'greater')
print(f'p-value: {results.pvalue}')
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-value: [1.88503944e-31]
# Отвергаем нулевую гипотезу

# %% [markdown]
# Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.
#
# H0: Клиенты с подпиской и без приносят одинаковое количество денег.
#
# H1: Подписчики приносят больше прибыли.
#
# Можно предположить, что прибыль от подписчиков больше чем от людей без подписки. Предположу, что грамотная рекламная кампания подписки на сервис сможет привлечь бОльшее количество текущих клиентов сегмента без подписки в сегмент подписчиков и увеличить прибыль сервиса.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# После исправления расчета выручки поменяется и вывод третьего стат теста

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что происходит, когда ты подаешь на стат тест две некорректно рассчитанные выборки
#
#         total1['revenue'], total0['revenue']
#
# Например у пользователя №1 в total1['revenue'], ты 3 раза добавил ежемесячную подписку к выручке за ноябрь месяц, это суммы
#
#         343, 295 и 295
#
# т.е. вместо одной суммы в 451 руб. стат тест проверяет три совершенно других числа  343, 295 и 295

# %%
# check
df1['revenue'].head(12)
# Out:
#                                    sum
# month user_id subscription_type
# 1     1       ultra              451.0
#       3       ultra              277.0
#       5       ultra              277.0
#       7       ultra              367.0
#       12      ultra              397.0
#       13      ultra              451.0
#       14      ultra              409.0
#       15      ultra              433.0
#       20      ultra              373.0
#       22      ultra              277.0
#       25      ultra              301.0
#       26      ultra              367.0

# %%
# check
# df1[df1['user_id'] == 1][['user_id', 'distance',   'date', 'month', 
#        'subscription_type', 'minute_price', 'start_ride_price',
#        'subscription_fee', 'amount', 'duration', 'revenue']]

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы (Н0 и Н1) не сформулированы
#
# Код проверки некорректный
#
#         if results.pvalue < alpha:
#             print('Выручка существенно не отличается')
#         else:
#             print('Выручка от подписчиков больше')

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поменять выборки для третьего стат теста, т.к. он выполнен на агрегированных данных — мы сгруппировали все данные за год
#
#         rev1_df['Выручка'], rev0_df['Выручка']
#
# Для корректного выполнения стоит использовать выборку с данными с помесячной оплатой для каждого пользователя

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить все выводы, добавить акценты с точки зрения бизнеса

# %% [markdown]
# 6.4. Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# Для проверки данной гипотезы подойдет односторонний (левосторонний) тест о равенстве средних для зависимых выборок.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         Для проверки данной гипотезы подойдет односторонний тест о равенстве средних для зависимых выборок.
#
# Левостороннюю или правостороннюю?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит уточнить какую гипотезу будешь проверять: одностороннюю или двустороннюю
#
# Подсказка
#
#         ... Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. ...

# %% [markdown]
# Общий вывод:
#
# Среди всех пользователей есть 2 вида: те, кто катается на самокате в пределах километра, и те, кто катается 3-5 килметров. Есть предположение, что первые пользуются самокатами для регулярного передвижения от станций метро до дома. Они являются самыми стабильными.
#
# Согласно статистике, подписчиков среди всех пользователей примерно треть. Люди с подпиской чаще всего пользуются услугами самокатов для путешествий на расстояние в 3 км. Размах частот небольшой. Возможно, это связано с тем, что люди с подпиской - постояльцы, которые пользуются одними маршрутами. Люди без подписок более разношерстны. Их средняя дистанция - от 2 до 4,5 км. Относительно подписчиков, данная каста потребителей гораздо чаще берут самокат на расстояние до 1 км.
#
# Подписчики, в среднем катаются на самокатах 13 - 23 минут. Насколько я понимаю, постояльцы с подпиской катаются по одним маршрутам и за одинаковый временной интервал.
#
# Судя по результатам Т-теста:
#
# Пользователи с подпиской, скорее всего, проводят на самокате бОльшее количество времени, чем люди без подписки.
#
# Исходя из полученного результата можно предположить, что подпичики проезжают целевые 3120 м. Самокаты не подвержены ускоренной порче.
#
# Можно предположить, что прибыль от подписчиков больше чем от людей без подписки. Предположу, что грамотная рекламная кампания подписки на сервис сможет привлечь бОльшее количество текущих клиентов сегмента без подписки в сегмент подписчиков и увеличить прибыль сервиса.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я, скорее всего, не совсем понятно сделал вывод. Речь идет о том, что денег подписчики и люди без подписки приносят разное количество. Акцент на рекламной кампании был сделан, потому что подписчики приносят больше прибыли. Если случится переход доли юзеров в подписчиков, то прибыли станет еще больше.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить итоговый вывод
#
#         Нельзя утверждать, что прибыль от подписчиков и людей без подписки одинаковая. Предположу, что грамотная рекламная кампания подписки на сервис сможет привлечь бОльшее количество текущих клиентов сегмента без подписки и увеличить прибыль сервиса.
#
# мы отвергаем Н0 и склоняемся к Н1, а Н1 говорит, что
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить итоговый вывод
#
#         Пользователи с подпиской и без, скорее, пользуются услугами сервиса одинаковое количество времени.
#
#         Подпичики проезжают целевые 3120 м. Скорее всего износ самокатов может быть выше предполагаемого. Это может сказаться на итоговой чистой прибыли.
#
#         Нельзя утверждать, что прибыль от подписчиков и людей без подписки одинаковая. Предположу, что грамотная рекламная кампания подписки на сервис сможет привлечь бОльшее количество текущих клиентов сегмента без подписки и увеличить прибыль сервиса.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить итоговый вывод

# %% [markdown]
# #### check

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Большинство руководителей, экономя свое время, начинают читать отчет аналитика с итогового вывода, и только найдя в нем интересную информацию могут проглядеть весь остальной отчет, но большая часть внимания будет сосредоточена на итоговых выводах.
#
# Стоит добавить 3-4 пары чисел (раскрывающие поведение клиентов) + сравнение показателей годовой и среднемесячной выручки по двум тарифам за 2021 год
#
# Можно добавить итоговую рекомендацию бизнесу

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования деятельности компании
#
# Критические ❌ комментарии:
#
#  + добавить название проекту
#  + поправить графики
#  + проверить размерность таблиц и  пропуски после объединения таблиц
#  + округление
#  + расчет выручки
#  + в разделе проверки гипотез пересмотреть все стат тесты, поменять выборки, добавить Н0 и Н1, выводы
#  + добавить статистики в промежуточные выводы
#  + прочие
#
# Стоит обратить внимание на ⚠️ комментарии...
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# Или ты не понимаешь, как выполнить эти шаги? Тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос в проекте и опять отправить его на проверку — так я смогу тебе ответить

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Примеры объединения таблиц, общая справка](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# [Примеры объединения таблиц, Федоров Д.](https://dfedorov.spb.ru/pandas/08.%20%D0%9A%D0%B0%D0%BA%20%D0%BE%D0%B1%D1%8A%D0%B5%D0%B4%D0%B8%D0%BD%D0%B8%D1%82%D1%8C%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%B5%20%D0%B8%D0%B7%20%D0%BD%D0%B5%D1%81%D0%BA%D0%BE%D0%BB%D1%8C%D0%BA%D0%B8%D1%85%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86_.html?ysclid=lklv5hyic8790467123)
#
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
#
# В помощь — как реализовать интерактивный план проекта вручную, смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
#
# [Базовый обзор распределений в статистике](https://qwertybox.ru/articles/242302/)
#
# [Как использовать биномиальное распределение в Python](https://www.codecamp.ru/blog/binomial-distribution-python/?ysclid=lmjbdt49de135513011)
#
# [Объяснение P-значений и статистической значимости](https://www.codecamp.ru/blog/p-values-statistical-significance/?ysclid=lm88qnc76l397155692)

# %% [markdown]
# ## Бонус

# %% [markdown]
# ###### Задача 7.1 — декомпозиция
#
# + Отделу маркетинга GoFast поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум 100 существующих клиентов должны продлить эту подписку.
#
# + То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж.
#
# + Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают 10 % пользователей.
#
# + Выясните, какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5 %.
#
# + Подберите параметры распределения, описывающего эту ситуацию, постройте график распределения и сформулируйте ответ на вопрос о количестве промокодов.

# %% [markdown]
# + 100 существующих клиентов должны продлить эту подписку.
#  + т.е. мы ищем х - кол-во промокодов, которое мы раздадим, чтобы сохранить 100 клиентов

# %% [markdown]
# + может либо отказаться от неё, либо продлить
#  + т.е. два исхода

# %% [markdown]
# + подписку продлевают 10 % пользователей
#  + т.е. из кол-ва Х, которое мы найдем и по которому разошлем промокоды, полагаясь на предыдущий опыт, продлят подписку 10%

# %% [markdown]
# + вероятность не выполнить план была примерно 5 %
#  + т.е. мы должны найти вероятность успеха нашей акции 1-0,05 = 95%
#  + этот план будет иметь свою вероятность исполнения при разном кол-ве Х, т.е. если мы выберем Х = 1000, вероятность успеха будет равна А, при 2000 промокодах, вероятность будет равна В. Но, увеличивая кол-во промокодов, мы увеличиваем трудозатраты ... По этой причине нас устроит вероятность успеха 95%, для которой и предстоит рассчитать кол-во промокодов Х

# %% [markdown]
# Получается задача делиться на две части
#
# + число положительных исходов должно быть равно 100-ам
#
# + но вероятность такого события должна быть равна 95%

# %% [markdown]
# Урок
#
# Percent Point Function для нормального распределения
# + Ранее вы познакомились с функцией распределения, или кумулятивной функцией распределения.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />меняем norm на binom
#
#
# https://www.statology.org/binompdf-vs-binomcdf/
#
# немного перефразируем известный сайт
#
#     1 - binom.cdf(k, n, p):
#
# Разность ⬆⬆⬆ находит вероятность того, что k успешных попыток или меньше произойдет в течение n испытаний, где вероятность успеха в данном испытании равна p.

# %%
from scipy.stats import binom

#calculate binomial probability
1 - binom.cdf(k=100, n=1000 , p=0.1)
# Out:
# 0.4734009187048347

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Получается вероятность успеха при раздаче 1000 промокодов, будет равна 47,3%
#
# Остается дотянуть до 95%

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для второй задачи подойдет этот пример, осталось самостоятельно рассчитать
#
#         # математическое ожидание
#
#         # стандартное отклонение
#
# и немного поменять алгоритм последней части расчета

# %%
from scipy import stats as st

# математическое ожидание
mu = 1000
# стандартное отклонение
sigma = 100

# задаём нормальное распределение с математическим ожиданием 1000 
# и стандартным отклонением 100
distr = st.norm(1000, 100) 

# значение, для которого хотим найти вероятность
x = 1150

# считаем вероятность получить значение больше x
result = 1 - distr.cdf(x)
print(result)
# Out:
# 0.06680720126885809

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Эту задачу можно проверить на графиках из урока «Функция нормального распределения»
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Примеры особенности объединения, в т.ч. с параметрами по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении

# %%
dfg1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

dfr4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
        "E": [np.nan, np.nan, np.nan, np.nan]
    },
    index=[2, 3, 6, 0],
)

# %%
display(dfg1, dfr4)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     B   D   F   E
# 2  B2  D2  F2 NaN
# 3  B3  D3  F3 NaN
# 6  B6  D6  F6 NaN
# 0  B7  D7  F7 NaN

# %%
dfg1.merge(dfr4, left_on=dfg1.index, right_on=dfr4.index, how='outer')
# Out:
#    key_0    A  B_x    C  D_x  B_y  D_y    F   E
# 0      0   A0   B0   C0   D0   B7   D7   F7 NaN
# 1      1   A1   B1   C1   D1  NaN  NaN  NaN NaN
# 2      2   A2   B2   C2   D2   B2   D2   F2 NaN
# 3      3   A3   B3   C3   D3   B3   D3   F3 NaN
# 4      6  NaN  NaN  NaN  NaN   B6   D6   F6 NaN

# %%
dfg1.merge(dfr4, 'outer')
# Out:
#      A   B    C   D    F   E
# 0   A0  B0   C0  D0  NaN NaN
# 1   A1  B1   C1  D1  NaN NaN
# 2   A2  B2   C2  D2   F2 NaN
# 3   A3  B3   C3  D3   F3 NaN
# 4  NaN  B6  NaN  D6   F6 NaN
# 5  NaN  B7  NaN  D7   F7 NaN

# %%
dfg1.merge(dfr4)
# Out:
#     A   B   C   D   F   E
# 0  A2  B2  C2  D2  F2 NaN
# 1  A3  B3  C3  D3  F3 NaN

# %%
dfg1.merge(dfr4, 'inner')
# Out:
#     A   B   C   D   F   E
# 0  A2  B2  C2  D2  F2 NaN
# 1  A3  B3  C3  D3  F3 NaN

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пример Закона больших чисел в действии (обратном), удалим 20 процентов (больше общепринятых 10%) всех данных из таблицы, где мы рассчитали выручку

# %%
# check
df['subscription_type'] = df.index.get_level_values(2)
df.columns = df.columns.to_flat_index()
df
# Out:
#                                  (distance, sum)  (speed, count)  \
# month user_id subscription_type
# 1     1       ultra                  7027.511294               2
#       3       ultra                  3061.777147               1
#       5       ultra                  3914.646990               1
#       7       ultra                  6478.080979               2
#       12      ultra                  3577.151148               1
# ...                                          ...             ...
# 12    1525    free                   4597.854350               1
#       1526    free                   3644.121544               1
#       1528    free                   3998.569324               1
#       1532    free                   6111.889853               2
#       1534    free                   2371.711192               1
#
#                                  (duration, sum)  (subscription_fee, max)  \
# month user_id subscription_type
# ...

# %%
df.columns = [' _ '.join(col).rstrip('_') for col in df.columns.values]

# %%
df.columns
# Out:
# Index(['distance & sum', 'speed & count', 'duration & sum',
#        'subscription_fee & max', 'revenue & sum', 'subscription_type & '],
#       dtype='object')

# %%
df
# Out:
#                                  distance & sum  speed & count  \
# month user_id subscription_type
# 1     1       ultra                 7027.511294              2
#       3       ultra                 3061.777147              1
#       5       ultra                 3914.646990              1
#       7       ultra                 6478.080979              2
#       12      ultra                 3577.151148              1
# ...                                         ...            ...
# 12    1525    free                  4597.854350              1
#       1526    free                  3644.121544              1
#       1528    free                  3998.569324              1
#       1532    free                  6111.889853              2
#       1534    free                  2371.711192              1
#
#                                  duration & sum  subscription_fee & max  \
# month user_id subscription_type
# ...

# %%
dfg_first = df.copy()

# %%
x = 'subscription_type & '
y = 'revenue & sum'

# %%
dfg_first.groupby(x)[y].mean().round(1).to_frame()
# Out:
#                       revenue & sum
# subscription_type &
# free                          328.6
# ultra                         362.8

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импортировал библиотеку в этом месте только ради примера, библиотеки стоит импортировать в начале проекта
#
#
#         import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
dfg_first.groupby(x)[y].hist(bins=200, figsize=(15,3), legend=True)
plt.title('Гистограммы ежесячной выручки двух групп пользователей')
plt.xlabel('руб.')
plt.ylabel('кол-во');

# %%
# копируем таблицу
dfg = dfg_first.copy()

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11331 entries, (1, 1, 'ultra') to (12, 1534, 'free')
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   distance & sum          11331 non-null  float64
#  1   speed & count           11331 non-null  int64
#  2   duration & sum          11331 non-null  float64
#  3   subscription_fee & max  11331 non-null  float64
#  4   revenue & sum           11331 non-null  float64
#  5   subscription_type &     11331 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 587.7+ KB

# %%
# удаляем данные, 20%
for col in dfg.columns:
    dfg.loc[dfg.sample(frac=0.2).index, col] = np.nan

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11331 entries, (1, 1, 'ultra') to (12, 1534, 'free')
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   distance & sum          9065 non-null   float64
#  1   speed & count           9065 non-null   float64
#  2   duration & sum          9065 non-null   float64
#  3   subscription_fee & max  9065 non-null   float64
#  4   revenue & sum           9065 non-null   float64
#  5   subscription_type &     9065 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 878.4+ KB

# %%
dfg.groupby(x)[y].mean().round(1).to_frame()
# Out:
#                       revenue & sum
# subscription_type &
# free                          329.1
# ultra                         363.1

# %%
dfg.groupby(x)[y].hist(bins=200, figsize=(15,3), legend=True)
plt.title('Гистограммы ежесячной выручки двух групп пользователей')
plt.xlabel('руб.')
plt.ylabel('кол-во');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Если сравнить средние значения выручки, даже после удаления 20-ти процентов данных (но одно важное условие — данные удалялись случайным образом), они изменились незначительно, как и характер распределения самих данных (кол-во данных уменьшилось, безусловно).
#
# Для сравнения представлен рисунок первой гистограммы
#
# ![image.png](attachment:image.png)
